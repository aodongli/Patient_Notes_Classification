# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
import spacy
import nltk
import re
from nltk import word_tokenize, sent_tokenize, text
from collections import Counter
pd.set_option("display.max_columns", None)

# %%
def preprocess(text):
    '''
    This function takes a string of text and does the following:
    - Remove initial "*" characters -- these are useless and extra noise
    - Convert alphabetic characters to lower case (Hello --> hello)
    - Replace numeric characters with "*" character.
    '''
    text = text.replace('*','').lower()
    text = re.sub('\d', '*', text)
    return text

def create_vocabulary(counter, threshold):
    '''
    @counter is a Counter object listing the number of times each token appears in the corpus
    @threshold = number of times a token must appear in corpus to be listed in vocabulary 
    '''
    Vocabulary = []
    for key in counter:
        value = counter[key]
        if value>=threshold:
            Vocabulary.append(key)
    vocab_indexer = dict()
    index_value = 1
    for word in Vocabulary:
        vocab_indexer[word] = index_value
        index_value = index_value+1
    return vocab_indexer

def token_to_index(tokens, token_indexer):
    """
    Function that transform a list of tokens in a document and coverts it to a list of token indices.
    @param tokens: list of tokens from document
    @param token_indexer: dictionary that maps each token in the vocabulary to an unique index
    """
    # Please DO NOT assign any ngram to index 0 which is reserved for PAD token
    index_list = []
    for token in tokens:
        try:  
            index_list.append(token_indexer[token])
        except:
            pass
    return index_list

# %% [markdown]
# --------

# %% [markdown]
# # MIMIC III

# %% [markdown]
# ## Create a dictionary that links each HADM_ID to a list of ICD Codes

# %% [markdown]
# Subject_ID can have multiple HADM_IDs (unique hospital admissions), but not the other way around.

# %%
Diagnoses_ICD = pd.read_csv('./MIMIC-III/DIAGNOSES_ICD.csv')
Diagnoses_ICD = Diagnoses_ICD[-Diagnoses_ICD['ICD9_CODE'].isnull()]
Diagnoses_ICD['Rolled_ICD'] = Diagnoses_ICD['ICD9_CODE'].str[0:3]

NumberCodes = len(Diagnoses_ICD['ICD9_CODE'].unique())
NumberRolled = len(Diagnoses_ICD['Rolled_ICD'].unique())

print('Unique ICD-9 codes:', NumberCodes, '\nUnique 3-Digit Codes:',NumberRolled)
print('HADM_IDs', len(Diagnoses_ICD['HADM_ID'].unique()), '\nSUBJECT_IDs', 
                     len(Diagnoses_ICD['SUBJECT_ID'].unique()))

Diagnoses_ICD.head()
# Out:
# Unique ICD-9 codes: 6984
# Unique 3-Digit Codes: 942
# HADM_IDs 58929
# SUBJECT_IDs 46517
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE Rolled_ICD
# 0    1297         109   172335      1.0     40301        403
# 1    1298         109   172335      2.0       486        486
# 2    1299         109   172335      3.0     58281        582
# 3    1300         109   172335      4.0      5855        585
# 4    1301         109   172335      5.0      4254        425

# %%
HADMID_Code_Dict = dict()
Unique_Visits = Diagnoses_ICD['HADM_ID'].unique()
for visit in Unique_Visits:
    VisitDF = Diagnoses_ICD[Diagnoses_ICD['HADM_ID']==visit].reset_index()
    ListOfICDs=[]
    for i in range(len(VisitDF)):
        ListOfICDs.append(VisitDF.loc[i, 'ICD9_CODE'])
    HADMID_Code_Dict[visit] = ListOfICDs

# %%
HADMID_Code_Dict[172335]
# Out:
# ['40301',
#  '486',
#  '58281',
#  '5855',
#  '4254',
#  '2762',
#  '7100',
#  '2767',
#  '7243',
#  '45829',
#  '2875',
#  '28521',
#  '28529',
#  '27541']

# %% [markdown]
# --------

# %% [markdown]
# ## Create a dictionary that links each HADM_ID to a Discharge Summary

# %%
NoteEvents = pd.read_csv('./MIMIC-III/NOTEEVENTS.csv')
Notes = NoteEvents[NoteEvents['CATEGORY'] == 'Discharge summary'].reset_index(drop=True)
Notes = Notes[['SUBJECT_ID','HADM_ID','CHARTDATE','DESCRIPTION', 'TEXT']]
Notes.head()
# Out:
# /Users/Brenton/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SUBJECT_ID   HADM_ID   CHARTDATE DESCRIPTION  \
# 0       22532  167853.0  2151-08-04      Report
# 1       13702  107527.0  2118-06-14      Report
# 2       13702  167118.0  2119-05-25      Report
# 3       13702  196489.0  2124-08-18      Report
# 4       26880  135453.0  2162-03-25      Report
#
#                                                 TEXT
# 0  Admission Date:  [**2151-7-16**]       Dischar...
# 1  Admission Date:  [**2118-6-2**]       Discharg...
# 2  Admission Date:  [**2119-5-4**]              D...
# 3  Admission Date:  [**2124-7-21**]              ...
# 4  Admission Date:  [**2162-3-3**]              D...

# %% [markdown]
# ### One problem we face here is that a HADM_ID might be associated with multiple discharge summaries.
#
# More specifically, an HADM_ID might have one "Report" and several "Addendums". Try to make it so that each HADM_ID is associated with EXACTLY one block of text. In order to do so, we'll need to concatenate texts for each HADM_ID.

# %%
NotesPerID = Notes.groupby('HADM_ID').count()[['TEXT']]
HADM_IDs_with_MultipleCounts = NotesPerID[NotesPerID['TEXT'] > 1].index
HADM_IDs_with_MultipleCounts #These are the HADM_IDs with more than one block of text.
# Out:
# Float64Index([100006.0, 100031.0, 100036.0, 100041.0, 100112.0, 100132.0,
#               100136.0, 100137.0, 100138.0, 100153.0,
#               ...
#               199883.0, 199907.0, 199917.0, 199918.0, 199951.0, 199952.0,
#               199961.0, 199962.0, 199964.0, 199988.0],
#              dtype='float64', name='HADM_ID', length=5720)

# %%
#NotesToAppend: rows of text that need to be merged according to HADM_ID
NotesToAppend = Notes[Notes['HADM_ID'].isin(HADM_IDs_with_MultipleCounts)]

UnchangedNotes = Notes[-Notes['HADM_ID'].isin(HADM_IDs_with_MultipleCounts)]
print(len(NotesToAppend), len(UnchangedNotes))
# Out:
# 12646 47006

# %%
ChangedNotes = pd.DataFrame()
for ID in HADM_IDs_with_MultipleCounts: #For each HADM_ID with multiple texts
    subdf = NotesToAppend[NotesToAppend['HADM_ID'] == ID] #create a smaller df with only that HADMID
    combined_text = subdf['TEXT'].str.cat() #combine all text in that column into one entry 
    subdf = subdf.drop_duplicates(subset='HADM_ID') #turn smaller df into 1-row df
    subdf['TEXT'] = combined_text 
    ChangedNotes = ChangedNotes.append(subdf)

# %%
TotalNotes = ChangedNotes.append(UnchangedNotes).reset_index(drop=True)
print(len(TotalNotes), len(TotalNotes['HADM_ID'].unique()))
# Out:
# 52726 52726

# %% [markdown]
# ### Preprocess text. Then count the number of times each token appears in the corpus.

# %%
'''
Preprocessing Steps
- Convert all alphabetical characters to lower case
- Eliminate any '*' characters that do not correspond to numbers
- Convert numeric characters to '*' -- so "2/2/2011" becomes "*/*/****"
'''
# Out:
# '\nPreprocessing Steps\n- Convert all alphabetical characters to lower case\n- Eliminate any \'*\' characters that do not correspond to numbers\n- Convert numeric characters to \'*\' -- so "2/2/2011" becomes "*/*/****"\n'

# %%
Corpus_Counts = Counter()
for i in range(len(TotalNotes)): #for each discharge summary
    text = TotalNotes['TEXT'][i]
    text_new = preprocess(text) #process text
    tokens = word_tokenize(text_new) #tokenize
    unigram_counts = Counter(tokens) #count number of unigrams
    Corpus_Counts.update(unigram_counts) #update the Counter for each discharge summary

# %%
#Corpus_Counts
# Out:
# Counter({'pneumoconiosis': 5,
#          'pain/fatigue/doe': 1,
#          '**/**.his': 1,
#          'moncytic': 4,
#          'low-phosphate': 1,
#          'w/ugib': 8,
#          'anti-retroviarals': 1,
#          'spray/nostril': 5,
#          'noc': 15,
#          'coarseness': 12,
#          'pa/lateral': 111,
#          'anterior/anterior-septal': 1,
#          'tra*p': 1,
#          'hmf-': 1,
#          'mg/kilo/min': 1,
#          'iliac-left': 1,
#          'pao*/fio*': 29,
#          '-shortgut': 1,
#          'aavandia': 1,
#          'saliene': 1,
#          'acquired-pneumonia': 2,
#          'over-breathing': 11,
#          'septdown': 1,
#          'lbut': 1,
#          'spep/upep': 94,
#          'junction/superior': 1,
#          'cpinal': 1,
#          'rigerous': 1,
#          'multisegmental': 6,
#          'reassigned': 3,
#          'sensitivities': 5237,
#          'rapid-acting': 1,
#          'mitazapine': 2,
#          'middle/posterior': 1,
#          'cp/sob/pnd/claudication': 1,
#          'cxr-lll': 2,
#          'w/tumor': 1,
#          '**gmdextrose': 1,
#          'solbuterol': 1,
#          'endocarditis/vegetation': 3,
#          'operator': 192,
#          'duo-neb': 3,
#          'sibling': 345,
#          'needed-anxiety': 1,
#          'femoral-dorsal': 1,
#          '-psoriatric': 1,
#          'dni/dni': 3,
#          'sub-i': 1,
#          'atlectatic': 2,
#          'acromegaly': 35,
#          'fall/syncopal': 2,
#          'asa/ibuprofen/acetaminophen': 1,
#          'syndesmotic': 12,
#          'svt/af': 1,
#          'myocarditis/cardiomyopathy': 2,
#          'emerald': 8,
#          'nonresolving': 4,
#          'oblong': 29,
#          'malignancy/chemotherapy': 1,
#          'focis': 1,
#          'drainaige': 6,
#          'asssit': 2,
#          'disease/ms': 1,
#          'myelomatous': 23,
#          'vulvulous': 2,
#          'neprhotoxic': 1,
#          'tropics': 1,
#          'metolozone': 20,
#          'incurring': 2,
#          'wine/nt': 2,
#          'tpe': 4,
#          'schnapps': 4,
#          'esld-': 7,
#          'coegentin': 1,
#          'diet/soft': 2,
#          'mtx/remicade': 2,
#          '-possibly': 6,
#          'hydrnephrosis': 2,
#          'staph/gram': 1,
#          'thicknedd': 1,
#          '-epogen': 10,
#          'change/hematoma': 1,
#          'atelectasis-infiltrate': 3,
#          'counsciousness': 1,
#          'normochronic': 2,
#          'januria': 2,
#          'er/pr/her-*': 1,
#          'axilla-above': 1,
#          'coworkers': 26,
#          'c/di/i': 1,
#          'neuro-a': 26,
#          'scoped': 223,
#          '-kaletra': 3,
#          'ipaa': 2,
#          'toall': 1,
#          'thrmobectomy': 1,
#          'dafalgan': 1,
#          'marnier': 1,
#          're-bolusing': 2,
#          '**/**/***/**/***': 2,
#          'hypomagnesemia': 239,
#          'vanco/zosyn-fluc': 1,
#          'author': 25,
#          'amiloride-hctz': 1,
#          'chiari/hcc/cirrhosis': 1,
#          'scopolamine': 658,
#          'braclet': 5,
#          'noisey': 1,
#          'avri': 1,
#          'colectomies': 4,
#          'failure/chronic': 14,
#          'unitelligable': 1,
#          'exceed': 972,
#          'cva-by': 1,
#          'nofever': 1,
#          'ns/**': 1,
#          'ligamentous/neural': 2,
#          'alt-***': 2674,
#          'cholest-**': 122,
#          'myomectomy-': 2,
#          'capit': 2,
#          'cannula/shovel': 1,
#          'brother/sister-in-law': 1,
#          'rubella-immune': 23,
#          'pheynlepherine': 1,
#          'hre': 6,
#          'uploaded': 47,
#          'deciphering': 1,
#          'pn*': 79,
#          'carfeully': 1,
#          'fio***': 19,
#          'inflmamation': 1,
#          'dementia/deprssion': 1,
#          'pod*-minimal': 1,
#          'hct=': 26,
#          'pinpoin': 1,
#          'thubs': 1,
#          'extubations': 36,
#          'nonsensical': 92,
#          'neurocystersarcosis': 2,
#          'encountered': 149,
#          'effusion.in': 1,
#          'over-sedation': 31,
#          'multivitian': 1,
#          'interferes': 27,
#          'ad/as': 1,
#          'resolve': 1866,
#          'chambered': 7,
#          'hola': 1,
#          'augmnetin': 1,
#          'qmo/we/fr': 2,
#          'fibrinoge-**': 37,
#          'diurresis': 2,
#          'nausea/discomfort': 1,
#          'interpretations': 22,
#          '*-valent': 47,
#          'precautions-mrsa/aspiration': 1,
#          'vancomycin/cefepime/levofloxacin': 7,
#          'arom': 19,
#          'metformin-sitaglipitin': 1,
#          'phtt': 1,
#          'ermana': 1,
#          'shakey': 8,
#          'rebolusing': 2,
#          'mutlipidous': 1,
#          'distenended': 1,
#          'afteroon': 3,
#          'mg/kd/day': 1,
#          'de-saturated': 1,
#          'third-look': 3,
#          'cognac': 9,
#          'cd*-*': 20,
#          'qtu-th-sa': 1,
#          'journal': 21,
#          'hypoalbuminaemia': 1,
#          'conj/sclera/lids': 5,
#          'rightfalx': 1,
#          'pancreatology': 1,
#          'e/a=': 1,
#          'chest/shoulder': 10,
#          'knocked': 42,
#          'glucose-***urean-**': 2,
#          'disesed': 2,
#          'complians': 1,
#          'folow': 45,
#          'settingwith': 1,
#          'cta-bilat': 92,
#          'ryhtym': 1,
#          'afterone': 1,
#          'valcade': 5,
#          'indeteminate': 1,
#          'fibulation': 1,
#          'ncsx': 1,
#          'adf': 4,
#          'faceplate': 8,
#          'wheeze/rhonchi': 12,
#          'cefaxone': 1,
#          'colchicine/probenecid': 1,
#          'ostiumm': 1,
#          'twenty-four': 312,
#          'bisphophonates': 1,
#          'aggitation': 261,
#          'grey-tinged': 1,
#          'ceftriaxone/flagy': 1,
#          'homocys-pnd': 2,
#          'brefringent': 1,
#          'flexitrack': 1,
#          'two-unit': 2,
#          'crossfilling': 2,
#          'retinal': 901,
#          'isoproteronal': 1,
#          '**-patient': 2,
#          '**adf': 1,
#          'acetycysteine': 3,
#          'pacemakre': 1,
#          'four-millimeter': 1,
#          'emboliztion': 1,
#          'aaox*': 2045,
#          'descneding': 1,
#          'microscopic': 449,
#          'maintenanace': 1,
#          'l.buttock': 2,
#          'choices/limit': 1,
#          'tolewrates': 1,
#          '-week': 42,
#          'r/g/s*/s*': 1,
#          'f/up': 55,
#          'ceftriaxone.pt': 1,
#          'short-normal': 1,
#          'iir': 5,
#          'femerol': 10,
#          'oxaliplatin/avastin/*fu': 1,
#          'emobolic': 3,
#          'grand-niece': 2,
#          'midlind': 1,
#          'tiw': 106,
#          '*.subcutaneous': 1,
#          'immunotyping': 6,
#          "lungs'": 1,
#          'depression-pt': 1,
#          'cell-mg': 6,
#          'dotty': 2,
#          'echerichia': 1,
#          'levolfoxacin': 1,
#          'ebi': 8,
#          'hcrf': 2,
#          'eryhtema': 11,
#          'flowmask': 1,
#          'underphtx': 1,
#          'icrease': 2,
#          '*-yr-old': 1,
#          'sepsic': 2,
#          'admissioni': 2,
#          'jejunotomy': 5,
#          'elderlh': 1,
#          'vanco/zosyn/fluconazole': 3,
#          'immodium/lipram': 1,
#          'hypercapnic': 184,
#          'w/placement': 3,
#          'bacteremia/port': 1,
#          'rehability': 2,
#          'i.': 493,
#          'laminotomies': 45,
#          'sphincterotomoy': 1,
#          'employment-': 5,
#          'intubated/seated': 1,
#          'pox=**': 26,
#          "lft's/inr": 1,
#          "mother's": 156,
#          'ip-wealling': 1,
#          'hepatice': 1,
#          'embolization/coiling': 1,
#          'pain.she': 1,
#          'non-threatening': 3,
#          'successufl': 1,
#          'advantage': 18,
#          '*.history': 9,
#          'dayquil': 5,
#          'cardiolipin': 29,
#          'reactivity': 125,
#          'removeed': 1,
#          'allergg': 1,
#          'gate': 42,
#          'standing-': 1,
#          'reasonunless': 1,
#          'physicallly': 1,
#          'months/patient': 1,
#          'maimal': 1,
#          'hypthyrodism': 1,
#          'retrolistheses': 1,
#          'midaz/fentanyl': 1,
#          'conversant/perseverative': 1,
#          'athroscopy': 6,
#          'amteropr': 1,
#          'whitsle-tip': 1,
#          'evisceration': 22,
#          'mcg/kg/minimal': 1,
#          'witihin': 2,
#          'intertrocanteric': 1,
#          'intabated': 3,
#          'schizophrenia/competence': 1,
#          'non-smoker/non-drinker': 2,
#          'therapeuic': 2,
#          'airborne': 13,
#          'viz': 1,
#          'incluing': 6,
#          'nsignificant': 1,
#          'hematom': 2,
#          'dovered': 1,
#          '*-*q*-*prn': 1,
#          'abnormality/ventricular': 19,
#          'bronchocele': 1,
#          '.um': 1,
#          'evaled': 13,
#          'monocular': 32,
#          '-folic': 103,
#          'vesselsplease': 2,
#          'cre-*': 14,
#          'hematomta': 1,
#          'gastritis/gerd': 15,
#          'carboplatin-responsive': 2,
#          'cystoides': 3,
#          'cathetreizedd': 1,
#          'neo-adjuvant': 20,
#          'liver/abd': 1,
#          'secretion': 391,
#          'parotids': 44,
#          '*.f/u': 3,
#          'phosphosoda': 2,
#          'breath': 49056,
#          'obstruction/perforation/incarceration': 1,
#          '-minor': 1,
#          'frequenting': 1,
#          'victory': 7,
#          'ribavirin-induced': 3,
#          'sough': 1,
#          'choking/aspiration': 2,
#          'sudde': 2,
#          'mucoceole': 1,
#          'inearly': 1,
#          'stalbe': 4,
#          'errythematic': 1,
#          'vsr': 1,
#          'pureed/dysphagic': 1,
#          'stretch': 94,
#          'metornidazole': 1,
#          '-meropenem': 9,
#          'shortnessof': 1,
#          "meinere's": 2,
#          'tw': 295,
#          'rfff': 2,
#          '*v-disease': 1,
#          'energy/excersize': 1,
#          'leukoctosis': 1,
#          'lcommunicate': 1,
#          'ffp/vitamin': 1,
#          'hand-foot': 3,
#          'cool': 2351,
#          'right-dominat': 2,
#          'bleach': 37,
#          'lorazepam/narcotics': 1,
#          'name/np': 1,
#          "**'s-**s": 7,
#          '*.preserved': 7,
#          'comments-ett': 4,
#          'hypophonia': 19,
#          'elsewere': 2,
#          'former': 4815,
#          'tha/tka': 2,
#          'cuspid': 1,
#          'tertialy': 1,
#          'radiation/ablation': 2,
#          'infection/endocrine': 1,
#          'prescreening': 2,
#          'breadycardic': 1,
#          'biker': 2,
#          'cath/no': 1,
#          'pansusceptible': 4,
#          'felodiopine': 1,
#          'dpn': 13,
#          'aa=': 1,
#          'o*-**intubated-intubated': 1,
#          'nicardopine': 5,
#          'ktx': 3,
#          'hea': 6,
#          'stomach/chf': 1,
#          'fentynyl/versed': 1,
#          'body/pacer': 1,
#          'coding': 24,
#          '-vague': 1,
#          'gastrict': 1,
#          'effusion/thickening': 3,
#          'vedio': 1,
#          'buss': 2,
#          'unsuitable': 25,
#          'alb=*': 4,
#          'immunocomprimise': 1,
#          'f-t-n': 4,
#          'aorticendocarditis': 1,
#          'clear-to': 1,
#          'w/overlying': 1,
#          'pain/pressure/tightness': 3,
#          'dextrostixs': 2,
#          'hydrochlorothyazide': 6,
#          'post-vp': 3,
#          'abntibiotics': 1,
#          'magoh': 1,
#          'nj-tube': 4,
#          'weaker': 441,
#          'streptoccocus': 5,
#          'isoniazid/pyridoxine': 1,
#          'toic/clonic': 1,
#          'extre-strength': 1,
#          'tobramyicin': 1,
#          'jvn': 1,
#          'd**ns': 7,
#          '**-**l': 18,
#          'esophagus/hiatal': 1,
#          'scared': 43,
#          "'primary": 1,
#          'cartoids': 1,
#          'imaging-': 3,
#          'self-catherization': 6,
#          'line/swan-ganz': 1,
#          'tibiotalocalcaneal': 3,
#          'overload/respiratory': 1,
#          'antiarryhthmics': 2,
#          'extremitiesm': 1,
#          'fumes': 27,
#          'aorto/common': 1,
#          '-fem': 8,
#          'abl*': 1,
#          'co-aptation': 1,
#          'chorathiazide': 1,
#          'abulance': 2,
#          'non-clean': 1,
#          'imbalance': 227,
#          'reexamine': 7,
#          'w/collaterals': 1,
#          'presses': 9,
#          'cr=*.*-*.*': 2,
#          'med/toxin': 1,
#          'upper-airway': 6,
#          'cfa-akpop-at': 1,
#          '-migraines-': 2,
#          'neurogeneticist': 1,
#          'aviation': 3,
#          'hemi-arthroplasty': 13,
#          'triest': 1,
#          'creating': 83,
#          'trochanter-off': 1,
#          'flashes/diaphoresis': 1,
#          'colonials': 1,
#          'hp/larynx': 1,
#          'use/tobacco': 1,
#          '-excessive': 2,
#          'pressor-support': 9,
#          'infartion': 11,
#          'tossed': 1,
#          'c***t': 1,
#          'head/pituitary': 1,
#          'np-cpap': 1,
#          'dic-like': 2,
#          '-covering': 1,
#          'w/bal=***': 2,
#          'hundry': 1,
#          'head-*': 2,
#          'loculation': 176,
#          'clinially': 3,
#          'cyanocobalamin-b**': 1,
#          'cbag': 3,
#          'nobumatone': 1,
#          'radiologist': 2078,
#          'hydrocephalus/': 3,
#          'retruning': 1,
#          '*.**g': 2,
#          'eneurysm': 1,
#          'rad/dp': 3,
#          'recovered/woken': 1,
#          'vertically-sutured': 1,
#          'edema/pericholecystic': 3,
#          'incidentemente': 1,
#          'sieman': 1,
#          'independantly': 27,
#          'benxodiazepines': 1,
#          'huaband': 1,
#          'ms/group': 1,
#          'vent-': 11,
#          'complex-': 3,
#          'eroision': 1,
#          'noesure': 1,
#          'pg/q': 1,
#          'debriding': 14,
#          '+clubbing': 18,
#          'expenses': 6,
#          'removed.patient': 1,
#          'extrabiliary': 1,
#          'extravisation': 5,
#          'lethargy/sob': 1,
#          '+opiod': 1,
#          'abusedisorder': 1,
#          'three/four': 3,
#          'phrenoesophageal': 2,
#          '-gu': 27,
#          'three-cord': 1,
#          'enzymesx*': 2,
#          'nausea/vomiting/presyncope/syncope/diaphoresis/nonradiating': 1,
#          'admissiom': 2,
#          '***mcg/**mcg': 5,
#          'carvedilol/lisinopril': 1,
#          '*/***mg': 77,
#          'pravacid': 1,
#          're-site': 5,
#          'amiocaproic': 1,
#          'depaced': 1,
#          'starvation/dehydration': 1,
#          'distension/abdominal': 1,
#          'cilostazil': 1,
#          '-alcohol': 78,
#          'listing': 128,
#          'invesions': 1,
#          'w/facial': 1,
#          'vre-bacteremia': 2,
#          'saucepan': 4,
#          'infrapical': 1,
#          'dyspnea/distress': 1,
#          'artery/ramus': 1,
#          'privileges': 19,
#          'nonbleeding..': 1,
#          'oncology-hematology': 1,
#          'myoglobinuria': 27,
#          '****s-****s': 1,
#          'overstated': 2,
#          'tia/cva-*': 2,
#          'regulation': 53,
#          'non-comfrot': 1,
#          'svt/hemodynamic': 1,
#          'provit': 1,
#          'crack-cocaine': 15,
#          'c-vad': 1,
#          'hb-a*c': 3,
#          'transdate': 1,
#          'illness/infection': 2,
#          'versadile': 1,
#          'demyelination': 89,
#          '+pan-s': 1,
#          'cousins': 116,
#          'endur-acin': 4,
#          'onse': 1,
#          'bronzy': 3,
#          'occiital': 1,
#          'toxidromes': 3,
#          'bilomas/hepatic': 2,
#          'pylorus/antrum': 1,
#          'cardioversion/defibrillation': 2,
#          'cardizem-cr': 1,
#          'bipap/': 1,
#          'lap/loa': 4,
#          'interventon': 2,
#          'distsal': 2,
#          'remain': 5908,
#          'carbomedics': 78,
#          'coumadization': 6,
#          'experimental': 87,
#          'paroxysm': 7,
#          'urether': 1,
#          'cheonic': 1,
#          'hospitalization.physical': 1,
#          'anxious/depressed': 1,
#          'services-pca': 1,
#          'tran-esophageal': 1,
#          'artifacts/small': 1,
#          'hypercholesterolema': 3,
#          'sibling-brother': 1,
#          '+pseudomonal': 1,
#          'vitamin/folate': 1,
#          'votaren': 2,
#          'extrpulmonary': 1,
#          'vua': 1,
#          'afib/pulmonary': 1,
#          'caltco*-**': 6287,
#          'day+***': 1,
#          'stenotrophomonas/enterobacter': 4,
#          'prominence/widening': 1,
#          'therapists': 250,
#          'abuser-': 1,
#          'foley/blood': 1,
#          'tacypneic': 12,
#          'hypoventilation/poor': 1,
#          'trachyarrhythmia': 1,
#          'unopacified': 31,
#          '.synthroid': 2,
#          'sustiva': 51,
#          'osms': 169,
#          'pain/angina': 7,
#          'dyskinesia': 149,
#          '*l/min/m*': 15,
#          'resepctively': 3,
#          'hallucinatory': 3,
#          'headstrike': 25,
#          '**.levoxyl': 1,
#          '-nails-': 1,
#          'autoregulation': 38,
#          'inferolaterally': 82,
#          'tmax**': 2,
#          'pain-killers': 3,
#          'v.fib': 16,
#          'bronscopy': 1,
#          'interincisal': 1,
#          'astrocytes': 9,
#          'rhochorus': 2,
#          '+c/o': 2,
#          '**cig/d': 2,
#          'genmcitbine': 1,
#          'autonomic/objective': 1,
#          '*g/ceftriaxone': 1,
#          "tm's": 1,
#          'euphoria': 2,
#          'lasix/morphine': 1,
#          'ampuation': 9,
#          'repositioned': 325,
#          '**pm.the': 1,
#          'pain/strain': 1,
#          'dysesthetic': 5,
#          'amputed': 4,
#          'rescuciation': 1,
#          'nutra-shake': 1,
#          'neck/head/brain': 1,
#          'afib.was': 1,
#          'guaifenesiin': 1,
#          'area-': 5,
#          'brewer': 2,
#          'sogrens': 1,
#          'itnernalc': 1,
#          'stand-alone': 3,
#          'coumadine': 11,
#          'meditation': 4,
#          'nitrite/**': 1,
#          'bloweing': 1,
#          'self-treat': 2,
#          'rij': 1234,
#          '**i': 2,
#          'flatyl': 1,
#          'oingoing': 1,
#          'arthrogram': 4,
#          'trop/cks': 1,
#          'hemohematometra': 1,
#          'microalb': 1,
#          'doxyclcline': 2,
#          'age-stable': 1,
#          '-aortofemoral': 1,
#          'notclearly': 1,
#          'c*': 7850,
#          'son/power': 3,
#          'agpars': 1,
#          'klaron': 1,
#          'basese': 1,
#          'agitated/tachypneic': 1,
#          'apirated': 1,
#          'hypermanic': 1,
#          'cartia-xt': 1,
#          'ileo-conduit': 3,
#          'bk': 211,
#          '-corrected': 1,
#          'pprom/ptl': 1,
#          '+e': 2,
#          'evodence': 1,
#          'enderectomy': 2,
#          '_____________________________': 7,
#          'requestd': 1,
#          'fulfill': 18,
#          'episode/code': 2,
#          'advised.pod': 1,
#          '-serial': 6,
#          'revascularization/aortic': 1,
#          'electrolyte-containing': 1,
#          'ms-': 49,
#          'jg-tube': 1,
#          'developedpulmonary': 1,
#          'nephrocaps': 1672,
#          '*/***/**/*': 15,
#          '-dayquil': 1,
#          'linear-type': 2,
#          's/s': 286,
#          'cyclosprine': 3,
#          'cntromr-negative': 6,
#          'hemplegic': 3,
#          'remvoed': 3,
#          'methgb-*': 78,
#          'eisenmenger': 11,
#          'suspect': 1097,
#          'attenuation': 2131,
#          'med-flighted': 89,
#          'depo': 23,
#          'vr': 64,
#          'diabetic/cardiac': 30,
#          'dark/possibly': 1,
#          'caugh': 6,
#          'snort': 6,
#          'quantified': 377,
#          'hemotypsis': 7,
#          'water-sealed': 2,
#          'esophageal/pleural': 1,
#          'bulkier': 1,
#          'ascites/liver': 4,
#          'fingings': 1,
#          'invents': 1,
#          'failreu': 1,
#          'conrinued': 2,
#          'impaired/cough': 1,
#          'aspirin**': 4,
#          'urologist': 859,
#          'dischargea': 1,
#          'stool/black': 1,
#          'dischargeon': 1,
#          'urethrorectal': 2,
#          'immuno': 17,
#          'non-translocated': 1,
#          'lower-than-expected': 1,
#          'tocolodex': 1,
#          'ortable': 1,
#          '================': 104,
#          'tracheo-bronchomalazcia': 2,
#          'pred/benedryl/cimetidine': 1,
#          'disease/cc/stomac': 1,
#          'squint': 2,
#          'toelerating': 1,
#          'lt**-**': 1,
#          'macroreentrant': 1,
#          'stool/mucous': 1,
#          'nacl-chond': 1,
#          'miming': 8,
#          'no-show': 1,
#          'registering': 11,
#          'leuk': 352,
#          'succinate': 5610,
#          "'": 15098,
#          'hythmia': 1,
#          'resembles': 25,
#          'drag': 7,
#          'coloryellow': 2,
#          'hr***s': 11,
#          'fibrillation-placed': 1,
#          'secretons': 2,
#          'sas/sib': 2,
#          'lungs-rt': 1,
#          'evengually': 1,
#          'stomach/antrum': 1,
#          'narcotics/benzos': 2,
#          'agitation/discomfort': 3,
#          'reamaining': 2,
#          'pairs/clusters': 33,
#          'antiemesis': 2,
#          'paramedian': 158,
#          'weakness/numbness/loss': 2,
#          'cyscoscopy': 1,
#          'yes-no': 10,
#          '*.alprazolam': 1,
#          'd/orif': 1,
#          'vodka/brandy': 1,
#          'adiminstration': 1,
#          'complimented': 4,
#          'mucusmembranes': 1,
#          'coorindated': 1,
#          '/bg': 1,
#          'spurum': 3,
#          'bronchoscopy-malignant': 1,
#          'lwer': 1,
#          'replaement': 2,
#          'quiaic': 1,
#          'malignancy-associated': 1,
#          'meq/daily': 1,
#          'eyelash': 6,
#          'erythromycins': 1,
#          'panfacial': 1,
#          'topicals': 7,
#          'orthostasis/hypovolemia': 1,
#          'pneiumonia': 1,
#          'suprasternal': 36,
#          'nut.tx.pulm.disord.reg': 1,
#          'pcwp=**mmhg': 18,
#          'fa*b': 9,
#          'latched': 1,
#          'hemorrhage/contusion': 12,
#          'colac': 1,
#          'indications/options': 1,
#          'multilobular': 21,
#          'embedded': 56,
#          'toxicity/renal': 1,
#          'emia': 1,
#          'abiotic': 1,
#          'cancer.r': 1,
#          'valuyes': 1,
#          'myelination': 6,
#          'despondence': 1,
#          'augmenti': 1,
#          'neoepinephrine': 4,
#          'asssesment': 1,
#          'acteminophen': 1,
#          'bs+*': 4,
#          'craniotomoy': 1,
#          'mid-jejunal': 1,
#          'untword': 1,
#          'camprol': 1,
#          'procedure.we': 1,
#          'epiglottis/retropharyngenal': 1,
#          'mbi-*': 6,
#          'pacerwire': 2,
#          'pain/neck': 6,
#          'sev': 21,
#          'colectomy/ileostomy/g-j': 2,
#          'panculutred': 1,
#          'plat-***': 1,
#          "/c'ed": 1,
#          'dispo-pt': 1,
#          'briskly.her': 1,
#          'sulcrafate': 32,
#          'andpropionibacterium': 1,
#          'e-v': 1,
#          '*.tonsillectomy': 3,
#          'obstructive/restrictive': 50,
#          '+mildly': 5,
#          'susegmental': 1,
#          'av-paced': 100,
#          'smokees': 1,
#          'korean': 63,
#          'raisins': 3,
#          'mod-markedly': 1,
#          'currettage': 1,
#          'cholecsytectomy': 4,
#          'w/wo': 32,
#          'perfenidone': 1,
#          '-cri-baseline': 1,
#          'notifing': 1,
#          'ofloxacin': 43,
#          'flag': 29,
#          'cyctitis': 1,
#          'na-k-atpase': 1,
#          'pseudomonas-': 7,
#          'polymer': 3,
#          'g*': 1634,
#          'pain/myalgias': 1,
#          '+paroxysmal': 2,
#          'oa/protusio': 1,
#          'marginal/am': 1,
#          'aieration': 1,
#          'etopaside': 1,
#          'hemotology': 5,
#          'being': 26112,
#          'papvr': 2,
#          'electrocardial': 1,
#          'pain/diarrhea': 36,
#          'splenocaval': 1,
#          'reachieved': 1,
#          'nonshifted': 1,
#          'workup/observation': 1,
#          'diffuculty': 14,
#          '*-start': 1,
#          'metorolol': 6,
#          'race': 678,
#          'girlfreinds': 1,
#          '-infantile': 1,
#          "bells'palsy": 1,
#          '.duodenitis': 1,
#          'fluctates': 2,
#          'comprise': 131,
#          'misnames': 2,
#          'tendinosis': 24,
#          'oxihood': 1,
#          'gastric/peptic': 1,
#          'leukonostoc': 1,
#          'pk-yrs': 16,
#          'popliteal-posterior': 4,
#          '-v-fib': 1,
#          'legioaires': 1,
#          'divert': 23,
#          'gd': 2,
#          '-ecasa': 1,
#          'post-transplant-pnd': 1,
#          'hr**s-***s': 1,
#          'dyspnea/pcp': 1,
#          'endogenous': 25,
#          'ppa': 2,
#          '-elavil': 1,
#          'infarction/ischemic': 1,
#          'xrt/surgery': 2,
#          'incontinenence': 1,
#          'hosptalisation': 1,
#          'eomi/no': 1,
#          'sochx': 51,
#          'todya': 4,
#          'academics': 2,
#          'addendum/discharge': 1,
#          'bifem-': 2,
#          'droopier': 2,
#          'mca/right': 1,
#          'emoval': 1,
#          'cement-bone.preliminary': 1,
#          'size/lesser': 1,
#          'f/e/n-renal': 1,
#          'lasrge': 2,
#          'policeman': 33,
#          'hypomagnesiema': 1,
#          '+poorly': 1,
#          'anidulofungin': 1,
#          'effusion/signs': 1,
#          'nlarged': 1,
#          'cirrhoisis': 7,
#          'hypermobile/partial': 1,
#          '*th/': 1,
#          '*.*d': 1,
#          'contstant': 2,
#          'infection-cultures': 1,
#          'distall': 2,
#          'vegatative': 3,
#          'anti-hepbc': 1,
#          'stable-to-minimally': 2,
#          'precedent': 2,
#          'subaxial': 4,
#          'admisinsted': 1,
#          'c/d/*': 1,
#          'hypergammaglobulinemia': 12,
#          'disks': 119,
#          'beguaic': 1,
#          'post-rbc': 2,
#          'frialdades': 1,
#          'beta-blockade/statin/asa': 1,
#          'moderate-to-low': 2,
#          'department/micu': 1,
#          'non-compaction': 12,
#          'ascites/encephalopathy': 3,
#          'secheduled': 1,
#          'becaome': 4,
#          'subsegemental': 11,
#          'htl': 1,
#          'weeks.size': 1,
#          'pain/psych': 1,
#          'schonlein': 2,
#          '*ppweek': 1,
#          'mi.cardiac': 1,
#          'dex/carb': 1,
#          'single-graft': 9,
#          'pca/occipital': 1,
#          'cardio-mediastinal': 5,
#          'explosive': 69,
#          'nectar-thicken': 1,
#          'not': 236497,
#          'end-gazed': 1,
#          'dysuria/hematuria/diarrhea/melana/brbpr': 1,
#          'struggling': 84,
#          'iend': 2,
#          'neuropleptics': 1,
#          'enterobiliary': 1,
#          'ereport': 1,
#          'oreserved': 1,
#          'neutphos': 1,
#          'dysdiadokinesis': 2,
#          'uptitrate': 175,
#          'wafers/tincture': 1,
#          'schizophrenia/mr': 1,
#          'wt-gain': 1,
#          '-r.': 5,
#          'hypersympathetic': 1,
#          '**.diuril': 1,
#          'ptcas/': 1,
#          'suspecious': 5,
#          'arf/hyperkalemia': 7,
#          'easiear': 1,
#          'encephalomalacic': 89,
#          'pletal': 159,
#          'hgb/plts': 1,
#          'cf': 95,
#          'smb': 1,
#          'nchct/ct-p/head': 1,
#          'homonimous': 2,
#          'ischemia/imminent': 1,
#          'sincerely': 15,
#          'msmts': 1,
#          '+poor': 8,
#          'cystoid': 2,
#          'supra-therapeutic': 43,
#          'posttransplant': 25,
#          'nasopharygeal': 4,
#          'tachypnea/anxiety': 2,
#          'napsin-a': 2,
#          '-morning': 1,
#          'paracenteses': 258,
#          'liking': 8,
#          'ne': 112,
#          'asymptomaic': 1,
#          'torsades/vt': 1,
#          'gasto-intestinal': 1,
#          'videal': 1,
#          'lansom': 1,
#          'this*': 48,
#          '-etoh/tobacco': 1,
#          'suncreen': 1,
#          'consultant/dr': 1,
#          'semi-purulent': 1,
#          'syrup': 3445,
#          ...})

# %% [markdown]
# ### Restrict vocabulary to tokens that appear at least 5 times. Then convert tokens to index numbers -- e.g. "I like pie" becomes [34, 120, 17]
#
#
# ### ISSUES
# - Out-of-Vocabulary words are COMPLETELY IGNORED. In prior assignments, we would often pad unknown words as 0.
# - Furthermore, we might want to link Out-of-Vocabulary words with the nearest token in our dictionary. This would help address misspellings. (Would this be too computationally intensive?)
# - Only tokenizing unigrams right now. Will need to tokenize sentences for hierarchical modelling?

# %%
vocabulary = create_vocabulary(Corpus_Counts, 5)
HADMID_Text_Dict = {}

for i in range(len(TotalNotes)): #for each discharge summary
    text = TotalNotes['TEXT'][i]
    text_new = preprocess(text)
    tokens = word_tokenize(text_new)
    indexed_document = token_to_index(tokens, vocabulary)
    hadm_id = TotalNotes.loc[i, 'HADM_ID']
    HADMID_Text_Dict[hadm_id] = indexed_document

# %%
HADMID_Text_Dict[100006][0:20]
# Out:
# [55966,
#  46943,
#  25823,
#  52900,
#  2748,
#  17347,
#  45907,
#  46943,
#  25823,
#  52900,
#  2748,
#  17347,
#  46943,
#  26647,
#  54334,
#  25823,
#  52900,
#  2748,
#  17347,
#  14965]

# %% [markdown]
# ----------------

# %% [markdown]
# ## Create One-to-One mapping between HADM_ID and SUBJECT_ID.
# Important because the training/test split will be determined by SubjectID

# %%
IDsOnly = TotalNotes[['HADM_ID','SUBJECT_ID']].drop_duplicates(subset='HADM_ID')
IDsOnly.sort_values(by='SUBJECT_ID').head()
# Out:
#         HADM_ID  SUBJECT_ID
# 46872  145834.0           3
# 9714   185777.0           4
# 25610  107064.0           6
# 2877   150750.0           9
# 20917  184167.0          10

# %% [markdown]
# --------

# %% [markdown]
# ## Create DataFrame so that each row is a HADM_ID; columns are SubjectID, Summary Text, and ICD-9 Codes

# %%
HADMID_Text_DF = pd.DataFrame(pd.Series(HADMID_Text_Dict)).rename(columns={0:'Summary'})
HADMID_Code_DF = pd.DataFrame(pd.Series(HADMID_Code_Dict)).rename(columns={0: 'ICD9_Codes'})

# %%
print(len(HADMID_Code_DF), len(HADMID_Text_DF))
# Out:
# 58929 52726

# %%
X = pd.merge(HADMID_Text_DF, HADMID_Code_DF, right_index=True, left_index=True).reset_index(). \
    rename(columns={'index':'HADM_ID'})        
    
TotalChart = pd.merge(IDsOnly, X, on='HADM_ID')

# %%
TotalChart.head()
# Out:
#   HADM_ID  SUBJECT_ID                                            Summary  \
# 0  100006        9895  [55966, 46943, 25823, 52900, 2748, 17347, 4590...
# 1  100031        6892  [55966, 46943, 25823, 52900, 3098, 17347, 4590...
# 2  100036       30078  [55966, 46943, 25823, 52900, 9564, 17347, 4590...
# 3  100041        9588  [55966, 46943, 25823, 52900, 53125, 17347, 459...
# 4  100112       25418  [55966, 46943, 25823, 52900, 9564, 17347, 4590...
#
#                                           ICD9_Codes
# 0  [49320, 51881, 486, 20300, 2761, 7850, 3090, V...
# 1  [4412, 4241, 42731, 4538, 5781, 4019, 4430, 73...
# 2  [4241, 42833, 9971, 41402, 2762, 4280, 42731, ...
# 3   [41401, 4414, 412, 496, 2449, 4019, 2749, V1582]
# 4            [41401, 4111, 25001, 4019, 2720, V1582]

# %% [markdown]
# ----------

# %% [markdown]
# # Save chart as JSON file

# %%
TotalChart.to_json('TotalChart.json')

# %%
pd.read_json('TotalChart.json').head()
# Out:
#       HADM_ID                                         ICD9_Codes  SUBJECT_ID  \
# 0      100006  [49320, 51881, 486, 20300, 2761, 7850, 3090, V...        9895
# 1      100031  [4412, 4241, 42731, 4538, 5781, 4019, 4430, 73...        6892
# 10     100154  [1541, 9974, 5601, 496, 51881, 4280, 48281, 99...       22389
# 100    101569  [99662, 03819, 00845, 40391, 51881, 1120, 5849...       17758
# 1000   116811  [4240, 5849, 42840, 28731, 4160, 4254, 5185, 9...       27712
#
#                                                 Summary
# 0     [55966, 46943, 25823, 52900, 2748, 17347, 4590...
# 1     [55966, 46943, 25823, 52900, 3098, 17347, 4590...
# 10    [55966, 46943, 25823, 52900, 53125, 17347, 459...
# 100   [55966, 46943, 25823, 52900, 53125, 17347, 459...
# 1000  [55966, 46943, 25823, 52900, 3098, 17347, 4590...

# %% [markdown]
# ------------

# %% [markdown]
# # Optional Section

# %%
### Save HADMID-Text dictionary as a numpy object
np.save('HADM_Text_Dict.npy', HADMID_Text_Dict)

# %%
### Save HADMID-ICD9 dictionary as a numpy object
np.save('HADM_Code_Dict.npy', HADMID_Code_Dict)

# %%
### Guide to loading numpy objects in Jupyter notebook
sample_dict = {'NYU': 'NY', 'Harvard': 'MA', 'Columbia': 'NY', 'Yale': 'CT'}
np.save('sample_dict.npy', sample_dict)

read_dictionary = np.load('./sample_dict.npy').item()
read_dictionary
# Out:
# {'Columbia': 'NY', 'Harvard': 'MA', 'NYU': 'NY', 'Yale': 'CT'}
